# %%
import pandas as pd

pd.options.display.max_columns = 500
pd.options.display.max_rows = 500

# %%
simi = pd.read_csv("Similar_port_1.csv")
mercado = pd.read_csv("estaticos_market.csv",index_col=0)

# %%
mercado = mercado.merge(simi,on="id")
result = mercado.sort_values("similarity",ascending=False,ignore_index=True)

# %%
result.iloc[142669:142670,:]
# Out:
#                                                        id  fl_matriz  \
# 142669  a449a7073ead322c2c6f438b383ec4232977897ae92776...       True
#
#                  de_natureza_juridica sg_uf natureza_juridica_macro  \
# 142669  SOCIEDADE EMPRESARIA LIMITADA    PI  ENTIDADES EMPRESARIAIS
#
#                    de_ramo     setor  idade_empresa_anos idade_emp_cat  fl_me  \
# 142669  COMERCIO VAREJISTA  COMERCIO            5.780822        5 a 10  False
#
#         fl_sa  fl_epp  fl_mei  fl_ltda dt_situacao  fl_st_especial  fl_email  \
# 142669  False   False   False    False  2013-01-17           False      True
#
#         fl_telefone fl_rm          nm_divisao  \
# 142669         True   NAO  COMERCIO VAREJISTA
#
#                                               nm_segmento fl_spa fl_antt  \
# 142669  COMERCIO; REPARACAO DE VEICULOS AUTOMOTORES E ...  False   False
#
#        fl_veiculo  vl_total_tancagem  vl_total_veiculos_antt  \
# ...

# %%
result.iloc[5500:5505,:]
# Out:
#                                                      id  fl_matriz  \
# 5500  463bb0d143e05bab57e38055b99f024701c79394816b18...       True
# 5501  00a50b7b24ce1e0ba18f52f5da8a0ea631e0b0c65d6e67...      False
# 5502  4c8ac7dd0d6bbc6c836fdc5ef424cceb0d5208f58bff01...       True
# 5503  2aae9a579b249d5cfa60541e73504cc1bb0a0ec56eceaf...       True
# 5504  c0ac520a25c3d00b775a548a42e5610eeb17610d7aad5e...       True
#
#        de_natureza_juridica sg_uf natureza_juridica_macro             de_ramo  \
# 5500  EMPRESARIO INDIVIDUAL    MA                  OUTROS  COMERCIO VAREJISTA
# 5501  EMPRESARIO INDIVIDUAL    MA                  OUTROS  COMERCIO VAREJISTA
# 5502  EMPRESARIO INDIVIDUAL    MA                  OUTROS  COMERCIO VAREJISTA
# 5503  EMPRESARIO INDIVIDUAL    MA                  OUTROS  COMERCIO VAREJISTA
# 5504  EMPRESARIO INDIVIDUAL    MA                  OUTROS  COMERCIO VAREJISTA
#
#          setor  idade_empresa_anos idade_emp_cat  fl_me  fl_sa  fl_epp  \
# ...

# %%
result.iloc[100000:100010,:]
# Out:
#                                                        id  fl_matriz  \
# 100000  e41b49c3f009eab4e868239499eb827e46791358857a2c...       True
# 100001  02bdd3b7f3ce7dfff9d67989628ccfb220b3206c3a007b...       True
# 100002  896413e3f70fcdf92e2be38aa93fb58ad90feaa2cab7a8...       True
# 100003  a0fc338c8ab403410fc296b1f511b2a9f915324c3139b4...       True
# 100004  738be2d22f056fccb11120dd2cb514c51ee73700aa8515...       True
# 100005  db562a34c6f21963be5ecce4db5664833cc59a875fa1e8...       True
# 100006  c83742c008beb000b3215f2f691ceac66b6b3d480318fa...       True
# 100007  86cb3c02f5b8571596edb726d608495121154b13fba895...       True
# 100008  c02c26864d9eec06ce4cf40cb71277daefae16d9cfb484...       True
# 100009  f22d7aa7274f90587fa1dd8b1e4b8bab0f748e47aab125...       True
#
#          de_natureza_juridica sg_uf natureza_juridica_macro  \
# 100000  EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 100001  EMPRESARIO INDIVIDUAL    PI                  OUTROS
# ...

# %%
result[result["similarity"]>0.94]
# Out:
#                                                        id  fl_matriz  \
# 0       f3ea648507f158e52e3e42baab59c1a00f552bf7a31dc6...       True
# 1       81271acf940e3ef2cd3036d4091b3b0aceae0271cffc49...       True
# 2       45174220df064048d5faafa28c1324c2b4ea4a1ac2c155...       True
# 3       04f6b9c70dd1dcdaeb73d790bce6488f5777467c2ed5c1...       True
# 4       370392576811c879b81a2c33f9646acb2f9a33b9bd73b4...       True
# ...                                                   ...        ...
# 138822  107b3868708d147f0a92873958ea26184dbbfc662ea32d...       True
# 138823  bf5e8c657d36cbf1fa235d0bc2a20c911ec87726e34f31...       True
# 138824  e0755db413909604272aaf0752dd4d31c55bc61f7aa0c0...      False
# 138825  1988772f0bfd401f9b2003c3d7ffa4da4cb283cf5da9a0...       True
# 138826  bf51aed390e013c90e7c14c5b3e201bf07ae3f5c32e273...       True
#
#                                      de_natureza_juridica sg_uf  \
# 0                                   EMPRESARIO INDIVIDUAL    PI
# ...

# %%
result["de_faixa_faturamento_estimado"].unique()
# Out:
# array(['DE R$ 81.000,01 A R$ 360.000,00', 'ATE R$ 81.000,00',
#        'DE R$ 360.000,01 A R$ 1.500.000,00', nan,
#        'DE R$ 1.500.000,01 A R$ 4.800.000,00', 'SEM INFORMACAO',
#        'DE R$ 4.800.000,01 A R$ 10.000.000,00',
#        'DE R$ 10.000.000,01 A R$ 30.000.000,00',
#        'DE R$ 30.000.000,01 A R$ 100.000.000,00',
#        'DE R$ 100.000.000,01 A R$ 300.000.000,00',
#        'DE R$ 300.000.000,01 A R$ 500.000.000,00',
#        'ACIMA DE 1 BILHAO DE REAIS',
#        'DE R$ 500.000.000,01 A 1 BILHAO DE REAIS'], dtype=object)

# %%
result["de_saude_tributaria"].unique()
# Out:
# array(['AMARELO', 'LARANJA', 'AZUL', 'VERDE', 'CINZA', nan, 'VERMELHO'],
#       dtype=object)
